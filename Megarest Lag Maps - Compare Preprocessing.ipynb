# %%
import numpy as np
import nibabel as nb
from nilearn import image, masking, plotting
import glob
import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
# %matplotlib notebook
plt.style.use('ggplot')

# %%
aifo_rest1_minimal_paths = glob.glob('/home/despo/dlurie/Projects/megarest_lag/analysis/sub*/Aifo/sub*_Aifo_rest_1_minimal_lag_map_lag6.nii.gz')
aifo_rest2_minimal_paths = glob.glob('/home/despo/dlurie/Projects/megarest_lag/analysis/sub*/Aifo/sub*_Aifo_rest_2_minimal_lag_map_lag6.nii.gz')

# %%
brain_mask_paths = '/home/despo/dlurie/Projects/megarest_lag/data/sub101/sub101_brain_mask.nii'

# %%
dlpfc_rest1_minimal_paths = glob.glob('/home/despo/dlurie/Projects/megarest_lag/analysis/sub*/Dlpfc/sub*_Dlpfc_rest_1_minimal_lag_map_lag6.nii.gz')
dlpfc_rest2_minimal_paths = glob.glob('/home/despo/dlurie/Projects/megarest_lag/analysis/sub*/Dlpfc/sub*_Dlpfc_rest_2_minimal_lag_map_lag6.nii.gz')

# %%
sham_rest1_minimal_paths = glob.glob('/home/despo/dlurie/Projects/megarest_lag/analysis/sub*/Sham/sub*_Sham_rest_1_minimal_lag_map_lag6.nii.gz')
sham_rest2_minimal_paths = glob.glob('/home/despo/dlurie/Projects/megarest_lag/analysis/sub*/Sham/sub*_Sham_rest_2_minimal_lag_map_lag6.nii.gz')

# %%
aifo_rest1_minimal_4d = image.smooth_img(aifo_rest1_minimal_paths, None)
aifo_rest2_minimal_4d = image.smooth_img(aifo_rest2_minimal_paths, None)

# %%
dlpfc_rest1_minimal_4d = image.smooth_img(dlpfc_rest1_minimal_paths, None)
dlpfc_rest2_minimal_4d = image.smooth_img(dlpfc_rest2_minimal_paths, None)

# %%
sham_rest1_minimal_4d = image.smooth_img(sham_rest1_minimal_paths, None)
sham_rest2_minimal_4d = image.smooth_img(sham_rest2_minimal_paths, None)

# %%
aifo_rest1_nonzero_arrays = []
for i in aifo_rest1_minimal_4d:
    i_data = i.get_data().ravel()
    i_data = i_data[i_data.nonzero()]
    aifo_rest1_nonzero_arrays.append(i_data)

# %%
aifo_rest2_nonzero_arrays = []
for i in aifo_rest2_minimal_4d:
    i_data = i.get_data().ravel()
    i_data = i_data[i_data.nonzero()]
    aifo_rest2_nonzero_arrays.append(i_data)

# %%
dlpfc_rest1_nonzero_arrays = []
for i in dlpfc_rest1_minimal_4d:
    i_data = i.get_data().ravel()
    i_data = i_data[i_data.nonzero()]
    dlpfc_rest1_nonzero_arrays.append(i_data)

# %%
dlpfc_rest2_nonzero_arrays = []
for i in dlpfc_rest2_minimal_4d:
    i_data = i.get_data().ravel()
    i_data = i_data[i_data.nonzero()]
    dlpfc_rest2_nonzero_arrays.append(i_data)

# %%
sham_rest1_nonzero_arrays = []
for i in sham_rest1_minimal_4d:
    i_data = i.get_data().ravel()
    i_data = i_data[i_data.nonzero()]
    sham_rest1_nonzero_arrays.append(i_data)

# %%
sham_rest2_nonzero_arrays = []
for i in sham_rest2_minimal_4d:
    i_data = i.get_data().ravel()
    i_data = i_data[i_data.nonzero()]
    sham_rest2_nonzero_arrays.append(i_data)

# %%
len(sham_rest1_minimal_4d)
# Out:
# 4

# %%
axes = []
for idx_x in range(4):
    for idx_y in range(4):
        axes.append((idx_x, idx_y))
        
f, axarr = plt.subplots(4, sharex=True)
for idx in range(4):
        sns.distplot(aifo_rest1_nonzero_arrays[idx], ax=axarr[idx])
        sns.distplot(aifo_rest2_nonzero_arrays[idx], ax=axarr[idx])
# Out:
# <img src="data:image/png;base64,...">

# %%
axes = []
for idx_x in range(4):
    for idx_y in range(4):
        axes.append((idx_x, idx_y))
        
f, axarr = plt.subplots(4, sharex=True)
for idx in range(4):
        sns.distplot(dlpfc_rest1_nonzero_arrays[idx], ax=axarr[idx])
        sns.distplot(dlpfc_rest2_nonzero_arrays[idx], ax=axarr[idx])
# Out:
# <img src="data:image/png;base64,...">

# %%
axes = []
for idx_x in range(4):
    for idx_y in range(4):
        axes.append((idx_x, idx_y))
        
f, axarr = plt.subplots(4, sharex=True)
for idx in range(4):
        sns.distplot(sham_rest1_nonzero_arrays[idx], ax=axarr[idx])
        sns.distplot(sham_rest2_nonzero_arrays[idx], ax=axarr[idx])
# Out:
# <img src="data:image/png;base64,...">

# %%
axes = []
for idx_x in range(4):
    for idx_y in range(4):
        axes.append((idx_x, idx_y))
        
f, axarr = plt.subplots(4, sharex=True)
for idx in range(4):
        sns.distplot(aifo_rest1_nonzero_arrays[idx], ax=axarr[idx])
        sns.distplot(dlpfc_rest1_nonzero_arrays[idx], ax=axarr[idx])
        sns.distplot(sham_rest1_nonzero_arrays[idx], ax=axarr[idx])
# Out:
# <img src="data:image/png;base64,...">

# %%
@interact(x=16)
def map_view(x):
    plotting.plot_epi(sham_rest1_minimal_4d[x], display_mode='x', cut_coords=7)
# Out:
# <img src="data:image/png;base64,...">

# %%
a = 4
type(a)
# Out:
# int
